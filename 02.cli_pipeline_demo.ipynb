# %% [markdown]
# # IceNet: Pipeline usage
#
# ## Context
#
# ### Purpose
# The first notebook demonstrated the use of high level command-line interfaces (CLI) of the IceNet library to download, process, train and predict from end to end.
#
# Now that you have gone through the basic steps of running the IceNet model via the CLI, you may wish to establish a framework to run the model automatically for end-to-end runs. This is often called a Pipeline. A Pipeline can schedule ongoing model runs or run multiple model variations simultaneously.
#
# This notebook illustrates the use of helper scripts from the IceNet pipeline repository for testing and producing operational forecasts.
#
# Please do go through the first notebook before proceeding with this, as the data download exists outside of the pipeline, and this is covered in detail in the first notebook. However, even so, this notebook has been designed to be run independent of other notebooks in this repository.
#
# This demonstrator notebook has been run on the British Antarctic Survey in-house HPC, however, the pipeline is by no means limited to running solely on HPCs.
#
# ### Highlights
# The key features of an end to end run are:
#
#  0. [Introduction](#0-Introduction)
#  1. [Setup](#1-Setup)
#  1. [Process](#2-Process)
#  1. [Train](#3-Train)
#  1. [Predict](#4-Predict)
#  1. [Visualise](#5-Visualise)
#
# **Note:** Steps 2, 3 and 4 are within the IceNet pipeline.
#
# ### Contributions
# #### Notebook
#
# James Byrne (author)
#
# Matthew Gascoyne
#
# Bryn Noel Ubald
#
# __Please raise issues [in this repository](https://github.com/icenet-ai/icenet-notebooks/issues) to suggest updates to this notebook!__
#
# Contact me at _jambyr \<at\> bas.ac.uk_ for anything else...
#
# #### Modelling codebase
# James Byrne (code author), Tom Andersson (science author)
#
# #### Modelling publications
# Andersson, T.R., Hosking, J.S., Pérez-Ortiz, M. et al. Seasonal Arctic sea ice forecasting with probabilistic deep learning. Nat Commun 12, 5124 (2021). https://doi.org/10.1038/s41467-021-25257-4
#
# #### Involved organisations
# The Alan Turing Institute and British Antarctic Survey

# %% [markdown]
# # 0. Introduction
#
# ## CLI vs Library vs Pipeline usage
#
# The IceNet package is designed to support automated runs from end to end by exposing the CLI operations demonstrated in the first notebook. These are simple wrappers around the library itself, and __any__ step of this can be undertaken manually or programmatically by inspecting the relevant endpoints.
#
# IceNet can be run in a number of ways: from the command line, the python interface, or as a pipeline.
#
# The rule of thumb to follow:
#
# * Use the [pipeline repository](https://github.com/icenet-ai/icenet-pipeline) if you want to run the end to end IceNet processing out of the box.
# * Adapt or customise this process using `icenet_*` commands described in this notebook and in the scripts contained in [the pipeline repo](https://github.com/icenet-ai/icenet-pipeline).
# * For ultimate customisation, you can interact with the IceNet repository programmatically (which is how the CLI commands operate.) For more information look at the [IceNet CLI implementations](https://github.com/JimCircadian/icenet2/blob/main/setup.py#L32) and the [library notebook](03.library_usage.ipynb), along with the [library documentation](#TODO).
#
# ## Using the Pipeline
#
# Now that you have gone through the basic steps of running the IceNet model via the high-level CLI commands, you may wish to establish a framework to run the model automatically for end-to-end runs. This is often called a Pipeline. A Pipeline can schedule ongoing model runs or run multiple model variations simultaneously. The pipeline is driven by a series of bash scripts, and an environmental `ENVS` configuration file.
#
# ![Diagram of Icenet and it's pipeline](./pipeline_diagram3.png "Icenet pipeline diagram displaying process blocks and data being processed from input on the left to output on the right, through the pipeline")
#
# To automatically produce daily IceNet forecasts we train multiple variations of the model, each with different starting conditions. We call this ensemble training. Then we run predictions for each model variation, producing a mean and error across the whole model ensemble. This captures some of the model uncertainty.
#
# ### Data
#
# This assumes that you have a data store in a `data/` folder (This can be the same as the `data/` directory generated when running through the first notebook). Since the data is common across pipelines, you do not need to redownload data that you have previously downloaded. It is recommended to symbolically link to a data store such that data is only downloaded when has not been downloaded previously.
#
# ### Ensemble Running
#
# To do this, an [icenet-pipeline](https://www.github.com/icenet-ai/icenet-pipeline) repository is available. The icenet-pipeline offers the `run_train_ensemble.sh` and `run_predict_ensemble.sh` script which operates similarly to the `icenet_train` and `icenet_predict` CLI commands demonstrated in the first notebook from the IceNet library.

# %% [markdown]
# ___
# # 1. Setup

# %% [markdown]
# ## Get the IceNet Pipeline
#
# Before progressing you will need to clone the icenet-pipeline repository. Assuming you have followed the directory structure from the first notebook:
#
#
# ```bash
# git clone https://www.github.com/icenet-ai/icenet-pipeline.git green
# ln -s green notebook-pipeline
# cd icenet-notebooks
# ```
#
# We clone a 'fresh' pipeline repository into a directory called 'green' (as an arbitrary way of identifying the fresh pipeline) and then symbolically link to it. This allows us to symbolically swap to another pipeline later if we want to.
#
# ```bash
# my-icenet-project/       <--- we're in here!
# ├── data/
# ├── icenet-notebooks/
# ├── green/               <--- Clone of icenet-pipeline
# └── notebook-pipeline@   <--- Symlink to the green/ `icenet-pipeline` repo we've just cloned into
# ```

# %%
# Viewing symbolically linked files.
# !find .. -maxdepth 1 -type l -ls
# Out:
# 317836352179    0 lrwxrwxrwx   1 bryald   ailab           4 Mar 13 23:25 ../notebook-pipeline -> blue

# %% [markdown]
# ## Configure the Pipeline

# %% [markdown]
# Move into the `notebook-pipeline` directory.

# %%
import os
os.chdir("../notebook-pipeline")
# !pwd
# Out:
# /data/hpcdata/users/bryald/git/icenet/blue

# %% [markdown]
# The pipeline is driven by environmental variables that are defined within an `ENVS` file.
#
# There is an example ENVS file (`ENVS.example`) in the `../notebook-pipeline` directory which is what ENVS is symbolically linked to by default.
#
# You can copy the `ENVS.example` file and create many variations to cover your usage scenario. Then, update the `ENVS` file symbolic link to the run you would like to go through.

# %% [markdown]
# As a demonstrator, we will change the existing `my-icenet-project/notebook-pipeline/ENVS` link that points to `my-icenet-project/notebook-pipeline/ENVS.example`.
#
# We will instead point it to the example in this notebook repository after copying it over `my-icenet-project/icenet-notebooks/ENVS.notebook_tutorial`.
#
# The ENVS files are typically collated within the `notebook-pipeline` repo, hence why we are copying the file across, this is not mandatory, but is being done for consistency.

# %%
# Unlink the existing symoblic link (under `my-icenet-project/notebook-pipeline/ENVS`)
# !unlink ENVS

# Copy over and point to the ENVS file from the icenet-notebooks repository
# !cp -v ../icenet-notebooks/ENVS.notebook_tutorial .
# !ln -s ENVS.notebook_tutorial ENVS
# Out:
# ‘../icenet-notebooks/ENVS.notebook_tutorial’ -> ‘./ENVS.notebook_tutorial’

# %% [markdown]
# Before running through this notebook, please update the following variables in the ENVS file to point to your icenet conda environment (if different to the default):
#
# <pre>
# export ICENET_HOME=${ICENET_HOME:-${HOME}/icenet/${ICENET_ENVIRONMENT}}
# export ICENET_CONDA=${ICENET_CONDA:-${HOME}/conda-envs/icenet}
# </pre>

# %%
# Looking at the symlinked files in the `notebook-pipeline` directory
# !find . -maxdepth 1 -type l -ls
# Out:
# 210460008733    0 lrwxrwxrwx   1 bryald   ailab          13 Mar 13 23:26 ./data -> ../green/data
# 210460008734    0 lrwxrwxrwx   1 bryald   ailab          22 Mar 14 02:27 ./ENVS -> ENVS.notebook_tutorial

# %% [markdown]
# ## Download data before initiating pipeline

# %% [markdown]
# As shown in the pipeline image at the top, the source data download is external to the pipeline since it is common across pipelines.
#
# Hence, the same commands from the first notebook can be used to download the required data into a data store (if not previously downloaded) and symbolically linked into in the working directory before using the pipeline. Please check the first notebook for details regarding the usage of these commands.
#
# **Please note that you do not need to redownload data you have already downloaded previously** (i.e., for date ranges you have previously downloaded into your data store).

# %%
# !icenet_data_masks south
# Out:
# [14-03-24 02:27:35 :INFO    ] - siconca ice_conc_sh_ease2-250_cdr-v2p0_200001021200.nc already exists
# [14-03-24 02:27:36 :INFO    ] - Saving ./data/masks/south/masks/active_grid_cell_mask_01.npy
# [14-03-24 02:27:36 :INFO    ] - siconca ice_conc_sh_ease2-250_cdr-v2p0_200002021200.nc already exists
# [14-03-24 02:27:36 :INFO    ] - Saving ./data/masks/south/masks/active_grid_cell_mask_02.npy
# [14-03-24 02:27:36 :INFO    ] - siconca ice_conc_sh_ease2-250_cdr-v2p0_200003021200.nc already exists
# [14-03-24 02:27:36 :INFO    ] - Saving ./data/masks/south/masks/active_grid_cell_mask_03.npy
# [14-03-24 02:27:36 :INFO    ] - siconca ice_conc_sh_ease2-250_cdr-v2p0_200004021200.nc already exists
# [14-03-24 02:27:36 :INFO    ] - Saving ./data/masks/south/masks/active_grid_cell_mask_04.npy
# [14-03-24 02:27:36 :INFO    ] - siconca ice_conc_sh_ease2-250_cdr-v2p0_200005021200.nc already exists
# [14-03-24 02:27:36 :INFO    ] - Saving ./data/masks/south/masks/active_grid_cell_mask_05.npy
# [14-03-24 02:27:36 :INFO    ] - siconca ice_conc_sh_ease2-250_cdr-v2p0_200006021200.nc already exists
# [14-03-24 02:27:36 :INFO    ] - Saving ./data/masks/south/masks/active_grid_cell_mask_06.npy
# [14-03-24 02:27:36 :INFO    ] - siconca ice_conc_sh_ease2-250_cdr-v2p0_200007021200.nc already exists
# [14-03-24 02:27:36 :INFO    ] - Saving ./data/masks/south/masks/active_grid_cell_mask_07.npy
# [14-03-24 02:27:36 :INFO    ] - siconca ice_conc_sh_ease2-250_cdr-v2p0_200008021200.nc already exists
# [14-03-24 02:27:36 :INFO    ] - Saving ./data/masks/south/masks/active_grid_cell_mask_08.npy
# [14-03-24 02:27:36 :INFO    ] - siconca ice_conc_sh_ease2-250_cdr-v2p0_200009021200.nc already exists
# [14-03-24 02:27:36 :INFO    ] - Saving ./data/masks/south/masks/active_grid_cell_mask_09.npy
# [14-03-24 02:27:36 :INFO    ] - siconca ice_conc_sh_ease2-250_cdr-v2p0_200010021200.nc already exists
# [14-03-24 02:27:36 :INFO    ] - Saving ./data/masks/south/masks/active_grid_cell_mask_10.npy
# [14-03-24 02:27:36 :INFO    ] - siconca ice_conc_sh_ease2-250_cdr-v2p0_200011021200.nc already exists
# [14-03-24 02:27:36 :INFO    ] - Saving ./data/masks/south/masks/active_grid_cell_mask_11.npy
# [14-03-24 02:27:36 :INFO    ] - siconca ice_conc_sh_ease2-250_cdr-v2p0_200012021200.nc already exists
# [14-03-24 02:27:36 :INFO    ] - Saving ./data/masks/south/masks/active_grid_cell_mask_12.npy

# %%
# !icenet_data_era5 south --vars uas,vas,tas,zg --levels ',,,500|250' 2022-12-29 2023-3-31
# Out:
# [14-03-24 02:27:38 :INFO    ] - ERA5 Data Downloading
# [14-03-24 02:27:38 :INFO    ] - Building request(s), downloading and daily averaging from ERA5 API
# [14-03-24 02:27:38 :INFO    ] - Processing single download for uas @ None with 3 dates
# [14-03-24 02:27:38 :INFO    ] - Processing single download for uas @ None with 90 dates
# [14-03-24 02:27:38 :INFO    ] - Processing single download for vas @ None with 3 dates
# [14-03-24 02:27:38 :INFO    ] - Processing single download for vas @ None with 90 dates
# [14-03-24 02:27:38 :INFO    ] - Processing single download for tas @ None with 3 dates
# [14-03-24 02:27:38 :INFO    ] - Processing single download for tas @ None with 90 dates
# [14-03-24 02:27:38 :INFO    ] - Processing single download for zg @ 500 with 3 dates
# [14-03-24 02:27:38 :INFO    ] - Processing single download for zg @ 500 with 90 dates
# [14-03-24 02:27:38 :INFO    ] - No requested dates remain, likely already present
# [14-03-24 02:27:38 :INFO    ] - Processing single download for zg @ 250 with 3 dates
# [14-03-24 02:27:38 :INFO    ] - No requested dates remain, likely already present
# [14-03-24 02:27:38 :INFO    ] - Processing single download for zg @ 250 with 90 dates
# [14-03-24 02:27:38 :INFO    ] - No requested dates remain, likely already present
# [14-03-24 02:27:38 :INFO    ] - No requested dates remain, likely already present
# [14-03-24 02:27:38 :INFO    ] - No requested dates remain, likely already present
# [14-03-24 02:27:38 :INFO    ] - No requested dates remain, likely already present
# [14-03-24 02:27:38 :INFO    ] - No requested dates remain, likely already present
# [14-03-24 02:27:38 :INFO    ] - No requested dates remain, likely already present
# [14-03-24 02:27:38 :INFO    ] - No requested dates remain, likely already present
# [14-03-24 02:27:38 :INFO    ] - No requested dates remain, likely already present
# [14-03-24 02:27:38 :INFO    ] - 0 daily files downloaded
# [14-03-24 02:27:38 :INFO    ] - No regrid batches to processing, moving on...
# [14-03-24 02:27:38 :INFO    ] - Rotating wind data prior to merging
# /data/hpcdata/users/bryald/git/icenet/icenet/icenet/data/interfaces/downloader.py:361: FutureWarning: Ignoring a datum in netCDF load for consistency with existing behaviour. In a future version of Iris, this datum will be applied. To apply the datum when loading, use the iris.FUTURE.datum_support flag.
#   iris.load_cube(sic_day_path, 'sea_ice_area_fraction')
# /data/hpcdata/users/bryald/git/icenet/icenet/icenet/data/interfaces/downloader.py:361: FutureWarning: Ignoring a datum in netCDF load for consistency with existing behaviour. In a future version of Iris, this datum will be applied. To apply the datum when loading, use the iris.FUTURE.datum_support flag.
#   iris.load_cube(sic_day_path, 'sea_ice_area_fraction')
# /data/hpcdata/users/bryald/git/icenet/icenet/icenet/data/interfaces/downloader.py:361: FutureWarning: Ignoring a datum in netCDF load for consistency with existing behaviour. In a future version of Iris, this datum will be applied. To apply the datum when loading, use the iris.FUTURE.datum_support flag.
#   iris.load_cube(sic_day_path, 'sea_ice_area_fraction')
# /data/hpcdata/users/bryald/git/icenet/icenet/icenet/data/interfaces/downloader.py:361: FutureWarning: Ignoring a datum in netCDF load for consistency with existing behaviour. In a future version of Iris, this datum will be applied. To apply the datum when loading, use the iris.FUTURE.datum_support flag.
#   iris.load_cube(sic_day_path, 'sea_ice_area_fraction')
# [14-03-24 02:27:39 :INFO    ] - Rotating wind data in ./data/era5/south/uas ./data/era5/south/vas
# [14-03-24 02:27:39 :INFO    ] - 0 files for uas
# [14-03-24 02:27:39 :INFO    ] - 0 files for vas

# %% [markdown]
# **Note:** We also make sure to also download sea-ice concentration data for the time period we're predicting for (in addition to the training range).
#
# In this case, the ENVS file defines the latest train date as being `2023-3-31`, and since we would like to forecast for `7` days (Also defined within the `ENVS` file under `export FORECAST_DAYS=7`), we should download up to `2023-4-7`.
#
# This will also be of use when comparing the prediction data.

# %%
# !icenet_data_sic south -d 2022-12-29 2023-4-7
# Out:
# [14-03-24 02:27:40 :INFO    ] - OSASIF-SIC Data Downloading
# [14-03-24 02:27:40 :INFO    ] - Downloading SIC datafiles to .temp intermediates...
# [14-03-24 02:27:40 :INFO    ] - Excluding 186 dates already existing from 100 dates requested.
# [14-03-24 02:27:40 :INFO    ] - Opening for interpolation: ['./data/osisaf/south/siconca/2022.nc', './data/osisaf/south/siconca/2023.nc']
# [14-03-24 02:27:40 :INFO    ] - Processing 0 missing dates

# %% [markdown]
# ___
# # 2. Process

# %% [markdown]
# The following command processes the downloaded data for the dates defined in the ENVS file.
#
# This is equivalent to running `icenet_process_era5`, `icenet_process_ora5`, `icenet_process_sic`, `icenet_process_metadata` commands from the IceNet library (as demonstrated in the first notebook).
#
# The arguments passed to these commands are obtained from the `PROC_ARGS_*` variables in the ENVS file.
#
# And, the dates that are processed are defined by the following variables in the ENVS file:
# * `TRAIN_START_*`
# * `TRAIN_END_*`
# * `VAL_START_*`
# * `VAL_END_*`
# * `TEST_START_*`
# * `TEST_END_*`
#
# This only needs to be run once unless the above variables need to be changed. Hence, it can be run as a precursor to the pipeline if the processed data does not need to change.

# %%
# !./run_data.sh south
# Out:
# CondaError: Run 'conda init' before 'conda activate'
#
# [14-03-24 02:27:47 :INFO    ] - Got 62 dates for train
# [14-03-24 02:27:47 :INFO    ] - Got 14 dates for val
# [14-03-24 02:27:47 :INFO    ] - Got 2 dates for test
# [14-03-24 02:27:47 :INFO    ] - Creating path: ./processed/notebook_tutorial_pipeline_south/era5
# [14-03-24 02:27:47 :DEBUG   ] - Setting range for linear trend steps based on 7
# [14-03-24 02:27:47 :INFO    ] - Processing 62 dates for train category
# [14-03-24 02:27:47 :INFO    ] - Including lag of 3 days
# [14-03-24 02:27:47 :INFO    ] - Including lead of 93 days
# [14-03-24 02:27:47 :DEBUG   ] - Globbing train from ./data/era5/south/**/[12]*.nc
# [14-03-24 02:27:47 :DEBUG   ] - Globbed 10 files
# [14-03-24 02:27:47 :DEBUG   ] - Create structure of 10 files
# [14-03-24 02:27:47 :INFO    ] - Processing 14 dates for val category
# [14-03-24 02:27:47 :INFO    ] - Including lag of 3 days
# [14-03-24 02:27:47 :INFO    ] - Including lead of 93 days
# [14-03-24 02:27:47 :DEBUG   ] - Globbing val from ./data/era5/south/**/[12]*.nc
# [14-03-24 02:27:47 :DEBUG   ] - Globbed 10 files
# [14-03-24 02:27:47 :DEBUG   ] - Create structure of 10 files
# [14-03-24 02:27:47 :INFO    ] - Processing 2 dates for test category
# [14-03-24 02:27:47 :INFO    ] - Including lag of 3 days
# [14-03-24 02:27:47 :INFO    ] - Including lead of 93 days
# [14-03-24 02:27:47 :DEBUG   ] - Globbing test from ./data/era5/south/**/[12]*.nc
# [14-03-24 02:27:47 :DEBUG   ] - Globbed 10 files
# [14-03-24 02:27:47 :DEBUG   ] - Create structure of 10 files
# [14-03-24 02:27:47 :INFO    ] - Got 2 files for tas
# [14-03-24 02:27:47 :INFO    ] - Got 2 files for uas
# [14-03-24 02:27:47 :INFO    ] - Got 2 files for vas
# [14-03-24 02:27:47 :INFO    ] - Got 2 files for zg250
# [14-03-24 02:27:47 :INFO    ] - Got 2 files for zg500
# [14-03-24 02:27:47 :INFO    ] - Opening files for uas
# [14-03-24 02:27:47 :DEBUG   ] - Files: ['./data/era5/south/uas/2022.nc', './data/era5/south/uas/2023.nc']
# [14-03-24 02:27:47 :DEBUG   ] - Could not import boto3, continuing with reduced functionality.
# [14-03-24 02:27:47 :DEBUG   ] - GDAL data found in package: path='/data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/rasterio/gdal_data'.
# [14-03-24 02:27:47 :DEBUG   ] - PROJ data found in package: path='/data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/rasterio/proj_data'.
# [14-03-24 02:27:47 :DEBUG   ] - Files have var names uas which will be renamed to uas
# [14-03-24 02:27:47 :DEBUG   ] - 121 dates in da
# [14-03-24 02:27:47 :INFO    ] - Filtered to 121 units long based on configuration requirements
# [14-03-24 02:27:48 :DEBUG   ] - No pre normalisation implemented for uas
# [14-03-24 02:27:48 :INFO    ] - Normalising uas
# [14-03-24 02:27:48 :DEBUG   ] - Generating norm-scaling min-max from 62 training dates
# [14-03-24 02:27:48 :DEBUG   ] - No post normalisation implemented for uas
# [14-03-24 02:27:48 :DEBUG   ] - Adding uas file: ./processed/notebook_tutorial_pipeline_south/era5/south/uas/uas_abs.nc
# [14-03-24 02:27:48 :INFO    ] - Opening files for vas
# [14-03-24 02:27:48 :DEBUG   ] - Files: ['./data/era5/south/vas/2022.nc', './data/era5/south/vas/2023.nc']
# [14-03-24 02:27:48 :DEBUG   ] - Files have var names vas which will be renamed to vas
# [14-03-24 02:27:48 :DEBUG   ] - 121 dates in da
# [14-03-24 02:27:48 :INFO    ] - Filtered to 121 units long based on configuration requirements
# [14-03-24 02:27:48 :DEBUG   ] - No pre normalisation implemented for vas
# [14-03-24 02:27:48 :INFO    ] - Normalising vas
# [14-03-24 02:27:48 :DEBUG   ] - Generating norm-scaling min-max from 62 training dates
# [14-03-24 02:27:48 :DEBUG   ] - No post normalisation implemented for vas
# [14-03-24 02:27:49 :DEBUG   ] - Adding vas file: ./processed/notebook_tutorial_pipeline_south/era5/south/vas/vas_abs.nc
# [14-03-24 02:27:49 :INFO    ] - Opening files for tas
# [14-03-24 02:27:49 :DEBUG   ] - Files: ['./data/era5/south/tas/2022.nc', './data/era5/south/tas/2023.nc']
# [14-03-24 02:27:49 :DEBUG   ] - Files have var names tas which will be renamed to tas
# [14-03-24 02:27:49 :DEBUG   ] - 121 dates in da
# [14-03-24 02:27:49 :INFO    ] - Filtered to 121 units long based on configuration requirements
# [14-03-24 02:27:49 :INFO    ] - Generating climatology ./processed/notebook_tutorial_pipeline_south/era5/south/params/climatology.tas
# [14-03-24 02:27:49 :WARNING ] - We don't have a full climatology (1,3) compared with data (1,2,3,12)
# [14-03-24 02:27:49 :DEBUG   ] - No pre normalisation implemented for tas
# [14-03-24 02:27:49 :INFO    ] - Normalising tas
# [14-03-24 02:27:49 :DEBUG   ] - Generating norm-scaling min-max from 62 training dates
# [14-03-24 02:27:49 :DEBUG   ] - No post normalisation implemented for tas
# [14-03-24 02:27:49 :DEBUG   ] - Adding tas file: ./processed/notebook_tutorial_pipeline_south/era5/south/tas/tas_anom.nc
# [14-03-24 02:27:49 :INFO    ] - Opening files for zg500
# [14-03-24 02:27:49 :DEBUG   ] - Files: ['./data/era5/south/zg500/2022.nc', './data/era5/south/zg500/2023.nc']
# [14-03-24 02:27:50 :DEBUG   ] - Files have var names zg500 which will be renamed to zg500
# [14-03-24 02:27:50 :DEBUG   ] - 121 dates in da
# [14-03-24 02:27:50 :INFO    ] - Filtered to 121 units long based on configuration requirements
# [14-03-24 02:27:50 :INFO    ] - Generating climatology ./processed/notebook_tutorial_pipeline_south/era5/south/params/climatology.zg500
# [14-03-24 02:27:50 :WARNING ] - We don't have a full climatology (1,3) compared with data (1,2,3,12)
# [14-03-24 02:27:50 :DEBUG   ] - No pre normalisation implemented for zg500
# [14-03-24 02:27:50 :INFO    ] - Normalising zg500
# [14-03-24 02:27:50 :DEBUG   ] - Generating norm-scaling min-max from 62 training dates
# [14-03-24 02:27:50 :DEBUG   ] - No post normalisation implemented for zg500
# [14-03-24 02:27:50 :DEBUG   ] - Adding zg500 file: ./processed/notebook_tutorial_pipeline_south/era5/south/zg500/zg500_anom.nc
# [14-03-24 02:27:50 :INFO    ] - Opening files for zg250
# [14-03-24 02:27:50 :DEBUG   ] - Files: ['./data/era5/south/zg250/2022.nc', './data/era5/south/zg250/2023.nc']
# [14-03-24 02:27:50 :DEBUG   ] - Files have var names zg250 which will be renamed to zg250
# [14-03-24 02:27:50 :DEBUG   ] - 121 dates in da
# [14-03-24 02:27:50 :INFO    ] - Filtered to 121 units long based on configuration requirements
# [14-03-24 02:27:50 :INFO    ] - Generating climatology ./processed/notebook_tutorial_pipeline_south/era5/south/params/climatology.zg250
# [14-03-24 02:27:51 :WARNING ] - We don't have a full climatology (1,3) compared with data (1,2,3,12)
# [14-03-24 02:27:51 :DEBUG   ] - No pre normalisation implemented for zg250
# [14-03-24 02:27:51 :INFO    ] - Normalising zg250
# [14-03-24 02:27:51 :DEBUG   ] - Generating norm-scaling min-max from 62 training dates
# [14-03-24 02:27:51 :DEBUG   ] - No post normalisation implemented for zg250
# [14-03-24 02:27:51 :DEBUG   ] - Adding zg250 file: ./processed/notebook_tutorial_pipeline_south/era5/south/zg250/zg250_anom.nc
# [14-03-24 02:27:51 :INFO    ] - Writing configuration to ./loader.notebook_tutorial_pipeline_south.json
# [14-03-24 02:27:54 :INFO    ] - Got 62 dates for train
# [14-03-24 02:27:54 :INFO    ] - Got 14 dates for val
# [14-03-24 02:27:54 :INFO    ] - Got 2 dates for test
# [14-03-24 02:27:54 :INFO    ] - Creating path: ./processed/notebook_tutorial_pipeline_south/osisaf
# [14-03-24 02:27:54 :DEBUG   ] - Setting range for linear trend steps based on 7
# [14-03-24 02:27:54 :INFO    ] - Processing 62 dates for train category
# [14-03-24 02:27:54 :INFO    ] - Including lag of 3 days
# [14-03-24 02:27:54 :INFO    ] - Including lead of 93 days
# [14-03-24 02:27:54 :DEBUG   ] - Globbing train from ./data/osisaf/south/**/[12]*.nc
# [14-03-24 02:27:54 :DEBUG   ] - Globbed 2 files
# [14-03-24 02:27:54 :DEBUG   ] - Create structure of 2 files
# [14-03-24 02:27:54 :INFO    ] - Processing 14 dates for val category
# [14-03-24 02:27:54 :INFO    ] - Including lag of 3 days
# [14-03-24 02:27:54 :INFO    ] - Including lead of 93 days
# [14-03-24 02:27:54 :DEBUG   ] - Globbing val from ./data/osisaf/south/**/[12]*.nc
# [14-03-24 02:27:54 :DEBUG   ] - Globbed 2 files
# [14-03-24 02:27:54 :DEBUG   ] - Create structure of 2 files
# [14-03-24 02:27:54 :INFO    ] - Processing 2 dates for test category
# [14-03-24 02:27:54 :INFO    ] - Including lag of 3 days
# [14-03-24 02:27:54 :INFO    ] - Including lead of 93 days
# [14-03-24 02:27:54 :DEBUG   ] - Globbing test from ./data/osisaf/south/**/[12]*.nc
# [14-03-24 02:27:54 :DEBUG   ] - Globbed 2 files
# [14-03-24 02:27:54 :DEBUG   ] - Create structure of 2 files
# [14-03-24 02:27:54 :INFO    ] - Got 2 files for siconca
# [14-03-24 02:27:54 :INFO    ] - Opening files for siconca
# [14-03-24 02:27:54 :DEBUG   ] - Files: ['./data/osisaf/south/siconca/2022.nc', './data/osisaf/south/siconca/2023.nc']
# [14-03-24 02:27:54 :DEBUG   ] - Could not import boto3, continuing with reduced functionality.
# [14-03-24 02:27:54 :DEBUG   ] - GDAL data found in package: path='/data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/rasterio/gdal_data'.
# [14-03-24 02:27:54 :DEBUG   ] - PROJ data found in package: path='/data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/rasterio/proj_data'.
# [14-03-24 02:27:54 :DEBUG   ] - Files have var names ice_conc which will be renamed to siconca
# [14-03-24 02:27:54 :DEBUG   ] - 186 dates in da
# [14-03-24 02:27:54 :INFO    ] - Filtered to 186 units long based on configuration requirements
# [14-03-24 02:27:55 :DEBUG   ] - ./data/masks already exists
# [14-03-24 02:27:55 :INFO    ] - Generating trend data up to 7 steps ahead for 186 dates
# [14-03-24 02:27:55 :INFO    ] - Generating 192 trend dates
# [14-03-24 02:27:55 :DEBUG   ] - ./data/masks already exists
# [14-03-24 02:28:00 :INFO    ] - Writing new trend cache for siconca
# [14-03-24 02:28:00 :DEBUG   ] - Adding siconca file: ./processed/notebook_tutorial_pipeline_south/osisaf/south/siconca/siconca_linear_trend.nc
# [14-03-24 02:28:00 :INFO    ] - No normalisation for siconca
# [14-03-24 02:28:00 :DEBUG   ] - No post normalisation implemented for siconca
# [14-03-24 02:28:01 :DEBUG   ] - Adding siconca file: ./processed/notebook_tutorial_pipeline_south/osisaf/south/siconca/siconca_abs.nc
# [14-03-24 02:28:01 :INFO    ] - Loading configuration ./loader.notebook_tutorial_pipeline_south.json
# [14-03-24 02:28:01 :INFO    ] - Writing configuration to ./loader.notebook_tutorial_pipeline_south.json
# [14-03-24 02:28:04 :INFO    ] - Creating path: ./processed/notebook_tutorial_pipeline_south/meta
# [14-03-24 02:28:04 :INFO    ] - Loading configuration ./loader.notebook_tutorial_pipeline_south.json
# [14-03-24 02:28:04 :INFO    ] - Writing configuration to ./loader.notebook_tutorial_pipeline_south.json
# [14-03-24 02:28:07 :INFO    ] - Got 0 dates for train
# [14-03-24 02:28:07 :INFO    ] - Got 0 dates for val
# [14-03-24 02:28:07 :INFO    ] - Got 0 dates for test
# [14-03-24 02:28:07 :INFO    ] - Creating path: ./network_datasets/notebook_tutorial_pipeline_south
# [14-03-24 02:28:07 :INFO    ] - Loading configuration loader.notebook_tutorial_pipeline_south.json
# [14-03-24 02:28:07 :DEBUG   ] - Adding 1 to uas_abs channel
# [14-03-24 02:28:07 :DEBUG   ] - Adding 1 to vas_abs channel
# [14-03-24 02:28:07 :DEBUG   ] - Adding 1 to siconca_abs channel
# [14-03-24 02:28:07 :DEBUG   ] - Adding 1 to tas_anom channel
# [14-03-24 02:28:07 :DEBUG   ] - Adding 1 to zg250_anom channel
# [14-03-24 02:28:07 :DEBUG   ] - Adding 1 to zg500_anom channel
# [14-03-24 02:28:07 :DEBUG   ] - Adding 1 to siconca_linear_trend channel
# [14-03-24 02:28:07 :DEBUG   ] - Adding 1 to cos channel
# [14-03-24 02:28:07 :DEBUG   ] - Adding 1 to land channel
# [14-03-24 02:28:07 :DEBUG   ] - Adding 1 to sin channel
# [14-03-24 02:28:07 :DEBUG   ] - Channel quantities deduced:
# {'cos': 1,
#  'land': 1,
#  'siconca_abs': 3,
#  'siconca_linear_trend': 7,
#  'sin': 1,
#  'tas_anom': 3,
#  'uas_abs': 3,
#  'vas_abs': 3,
#  'zg250_anom': 3,
#  'zg500_anom': 3}
#
# Total channels: 28
# [14-03-24 02:28:07 :DEBUG   ] - ./data/masks already exists
# [14-03-24 02:28:07 :DEBUG   ] - Using selector: EpollSelector
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/node.py:182: UserWarning: Port 8888 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 44766 instead
#   warnings.warn(
# [14-03-24 02:28:07 :INFO    ] - Dashboard at localhost:8888
# [14-03-24 02:28:07 :INFO    ] - Using dask client <Client: 'tcp://127.0.0.1:43903' processes=8 threads=8, memory=503.20 GiB>
# [14-03-24 02:28:08 :INFO    ] - 62 train dates to process, generating cache data.
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# [14-03-24 02:28:42 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000000.tfrecord
# [14-03-24 02:28:42 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000001.tfrecord
# [14-03-24 02:28:42 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000002.tfrecord
# [14-03-24 02:28:42 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000003.tfrecord
# [14-03-24 02:28:42 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000004.tfrecord
# [14-03-24 02:28:42 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000005.tfrecord
# [14-03-24 02:28:42 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000006.tfrecord
# [14-03-24 02:28:42 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000007.tfrecord
# [14-03-24 02:28:42 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000008.tfrecord
# [14-03-24 02:28:42 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000009.tfrecord
# [14-03-24 02:28:42 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000010.tfrecord
# [14-03-24 02:28:42 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000011.tfrecord
# [14-03-24 02:28:42 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000012.tfrecord
# [14-03-24 02:28:42 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000013.tfrecord
# [14-03-24 02:28:42 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000014.tfrecord
# [14-03-24 02:28:42 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000015.tfrecord
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# [14-03-24 02:29:15 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000016.tfrecord
# [14-03-24 02:29:15 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000017.tfrecord
# [14-03-24 02:29:15 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000018.tfrecord
# [14-03-24 02:29:15 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000019.tfrecord
# [14-03-24 02:29:15 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000020.tfrecord
# [14-03-24 02:29:15 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000021.tfrecord
# [14-03-24 02:29:15 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000022.tfrecord
# [14-03-24 02:29:15 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000023.tfrecord
# [14-03-24 02:29:15 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000024.tfrecord
# [14-03-24 02:29:15 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000025.tfrecord
# [14-03-24 02:29:15 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000026.tfrecord
# [14-03-24 02:29:15 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000027.tfrecord
# [14-03-24 02:29:15 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000028.tfrecord
# [14-03-24 02:29:15 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000029.tfrecord
# [14-03-24 02:29:15 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/train/00000030.tfrecord
# [14-03-24 02:29:15 :INFO    ] - 14 val dates to process, generating cache data.
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# [14-03-24 02:29:35 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/val/00000000.tfrecord
# [14-03-24 02:29:35 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/val/00000001.tfrecord
# [14-03-24 02:29:35 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/val/00000002.tfrecord
# [14-03-24 02:29:35 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/val/00000003.tfrecord
# [14-03-24 02:29:35 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/val/00000004.tfrecord
# [14-03-24 02:29:35 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/val/00000005.tfrecord
# [14-03-24 02:29:35 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/val/00000006.tfrecord
# [14-03-24 02:29:35 :INFO    ] - 2 test dates to process, generating cache data.
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /data/hpcdata/users/bryald/miniconda3/envs/icenet/lib/python3.11/site-packages/distributed/client.py:3166: UserWarning: Sending large graph of size 27.80 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# [14-03-24 02:29:45 :INFO    ] - Finished output ./network_datasets/notebook_tutorial_pipeline_south/south/test/00000000.tfrecord
# [14-03-24 02:29:45 :INFO    ] - Average sample generation time: 10.752348367984478
# [14-03-24 02:29:45 :INFO    ] - Writing configuration to ./dataset_config.notebook_tutorial_pipeline_south.json

# %% [markdown]
# ___
# # 3. Train

# %% [markdown]
# For producing forecasts in the described pipeline we actually run a set of models using the [model-ensembler](https://github.com/JimCircadian/model-ensembler) tool and as such there are convenience scripts for doing this as part of the end to end run.
#
# This requires the [model-ensembler](https://pypi.org/project/model-ensembler/) (`pip install model-ensembler`) module to be installed.
#
# Note that the model-ensembler will submit jobs and to configure the job scripts, you can access the templates that are used to generate them in the `.yaml` (in particular [`train.tmpl.yaml`](https://github.com/icenet-ai/icenet-pipeline/blob/main/ensemble/train.tmpl.yaml) for the training ensemble jobs) files in the `ensemble/` folder of the clone of the `icenet-pipeline` repository.

# %% [markdown]
# Many of the arguments for the following command are equivalent to the `icenet_train` command. However, the `-n` filters factor is actually `-f` in this example and we have additional arguments `-n` for the node to run on, `-p` for the pre_run script to use and `-j` for the number of simultaneous runs to execute on the SLURM cluster we use at BAS. However, these arguments are not necessarily required for other clusters, nor is the model-ensembler limited to running on SLURM (it can, at present, also run locally.)
#
# The pipeline repository shell scripts that provide this functionality are easily adaptable, as well as the ensemble itself which is stored in the pipeline repository under `/ensemble/`.
#
# _Please review the `-h` help option for the script to gain further insight the options available._

# %%
# !./run_train_ensemble.sh --help
# Out:
# Usage ./run_train_ensemble.sh LOADER DATASET NAME

# %% [markdown]
# The optional arguments (Some are not defined in this example):
# | argument | description                                                                                                  | value |
# |     ---: |:---                                                                                                          | :---  |
# |*-b*      | Batch size                                                                                                   | -     |
# |*-e*      | Number of epochs to train for                                                                                | 10     |
# |*-f*      | Scale the neural network channel sizes by this factor (reduces network size, priority over ENVS definition)  | 0.6   |
# |*-m*      | Memory required                                                                                              | 64gb  |
# |*-n*      | Node to run on                                                                                               | -     |
# |*-p*      | pre_run script to use                                                                                        | -     |
# |*-q*      | Maximum queue size                                                                                           | 4     |
# |*-r*      | Seed values for ensemble members (determines no. of ensemble members, overrides values in ENVS if specified) | -     |
# |*-j*      | No. of simultaneous runs to execute on the SLURM cluster                                                     | 5     |
#
#
# The positional arguments:
# | argument | description                                   | value                                        |
# |     ---: |:---                                           | :---                                         |
# |*LOADER*  | Name of loader: loader.{LOADER}.json          | notebook_tutorial_pipeline_south             |
# |*DATASET* | Name of dataset: dataset_config.{LOADER}.json | notebook_tutorial_pipeline_south             |
# |*NAME*    | Neural network output name                    | notebook_tutorial_pipeline_south_ensemble    |

# %%
# Positional Arguments
# argument 1: The loader json file:          loader.notebook_tutorial_pipeline_south.json
# argument 2: The dataset json file:         dataset_config.notebook_tutorial_pipeline_south.json
# argument 3: The trained network name:      name of trained network.
# !./run_train_ensemble.sh -e 10 -f 0.6 -m 64gb -q 4 -j 5 notebook_tutorial_pipeline_south notebook_tutorial_pipeline_south notebook_tutorial_pipeline_south_ensemble
# Out:
# ARGS: -e 10 -f 0.6 -m 64gb -q 4 -j 5 notebook_tutorial_pipeline_south notebook_tutorial_pipeline_south notebook_tutorial_pipeline_south_ensemble
# ARGS = -x arg_epochs=10 arg_filter_factor=0.6 mem=64gb arg_queue=4 , Leftovers: notebook_tutorial_pipeline_south notebook_tutorial_pipeline_south notebook_tutorial_pipeline_south_ensemble
# No. of ensemble members:  2
# Ensemble members:  42,46
# Running model_ensemble ./tmp.XA5Z04XC3C.train slurm -x arg_epochs=10 arg_filter_factor=0.6 mem=64gb arg_queue=4
# [14-03-24 02:29:47    :INFO    ] - Model Ensemble Runner
# [14-03-24 02:29:47    :INFO    ] - Validated configuration file ./tmp.XA5Z04XC3C.train successfully
# [14-03-24 02:29:47    :INFO    ] - Importing model_ensembler.cluster.slurm
# [14-03-24 02:29:47    :INFO    ] - Running batcher
# [14-03-24 02:29:47    :INFO    ] - Running command: mkdir -p ./results/networks
# [14-03-24 02:29:47    :INFO    ] - Start batch: 2024-03-14 02:29:47.619648
# [14-03-24 02:29:47    :INFO    ] - Running cycle 1
# [14-03-24 02:29:47    :INFO    ] - Start run notebook_tutorial_pipeline_south_ensemble-0 at 2024-03-14 02:29:47.620931
# [14-03-24 02:29:47    :INFO    ] - rsync -aXE ../template/ /data/hpcdata/users/bryald/git/icenet/blue/ensemble/notebook_tutorial_pipeline_south_ensemble/notebook_tutorial_pipeline_south_ensemble-0/
# [14-03-24 02:29:47    :INFO    ] - Start run notebook_tutorial_pipeline_south_ensemble-1 at 2024-03-14 02:29:47.623403
# [14-03-24 02:29:47    :INFO    ] - rsync -aXE ../template/ /data/hpcdata/users/bryald/git/icenet/blue/ensemble/notebook_tutorial_pipeline_south_ensemble/notebook_tutorial_pipeline_south_ensemble-1/
# [14-03-24 02:29:47    :INFO    ] - Templating /data/hpcdata/users/bryald/git/icenet/blue/ensemble/notebook_tutorial_pipeline_south_ensemble/notebook_tutorial_pipeline_south_ensemble-0/icenet_train.sh.j2 to /data/hpcdata/users/bryald/git/icenet/blue/ensemble/notebook_tutorial_pipeline_south_ensemble/notebook_tutorial_pipeline_south_ensemble-0/icenet_train.sh
# [14-03-24 02:29:47    :INFO    ] - Templating /data/hpcdata/users/bryald/git/icenet/blue/ensemble/notebook_tutorial_pipeline_south_ensemble/notebook_tutorial_pipeline_south_ensemble-1/icenet_train.sh.j2 to /data/hpcdata/users/bryald/git/icenet/blue/ensemble/notebook_tutorial_pipeline_south_ensemble/notebook_tutorial_pipeline_south_ensemble-1/icenet_train.sh
# [14-03-24 02:29:47    :INFO    ] - Submitted job with ID 6052820
# [14-03-24 02:29:48    :INFO    ] - Submitted job with ID 6052821
# [14-03-24 02:29:48    :WARNING ] - Could not retrieve job from list
# [14-03-24 03:07:00    :INFO    ] - notebook_tutorial_pipeline_south_ensemble-1 monitor got state COMPLETED for job 6052820
# [14-03-24 03:07:00    :INFO    ] - End run notebook_tutorial_pipeline_south_ensemble-1 at 2024-03-14 03:07:00.737202
# [14-03-24 03:07:32    :INFO    ] - notebook_tutorial_pipeline_south_ensemble-0 monitor got state COMPLETED for job 6052821
# [14-03-24 03:07:32    :INFO    ] - End run notebook_tutorial_pipeline_south_ensemble-0 at 2024-03-14 03:07:32.305879
# [14-03-24 03:07:32    :INFO    ] - Running command: /usr/bin/echo "No postprocessing in place for training ensemble"
# [14-03-24 03:07:32    :INFO    ] - Batch notebook_tutorial_pipeline_south_ensemble completed: 2024-03-14 03:07:32.312624
# Removing temporary configuration ./tmp.XA5Z04XC3C.train

# %% [markdown]
# This trains based on the processed data, and creates a sub-directory under `ensemble/` with the network name that contains each of the ensemble runs. This includes log files for debugging in case of any errors/issues in the training process.
#
# ```bash
# ensemble/
# └── notebook_tutorial_pipeline_south_ensemble/
#     ├── notebook_tutorial_pipeline_south_ensemble-0/
#     │   ├── *.err    <-- Error file
#     │   └── *.out    <-- Log file
#     └── notebook_tutorial_pipeline_south_ensemble-1/
#         └── ...
# ```
#
# The output from the trained network can be found in `results/networks`. The specifics of what is contained in here is out of scope of this notebook, but in general it stores the trained model, and a history of the losses and other metrics.
#
# ```bash
# results/
# └── networks/
#     └── notebook_tutorial_pipeline_south_ensemble/
#         ├── *.h5
#         ├── *.json
#         └── ...
# ```

# %% [markdown]
# ___
# # 4. Predict

# %% [markdown]
# In a similar manner to the training script, the `run_predict_ensemble` script will submit jobs to the HPC. The template corresponding to the prediction run is [`predict.tmpl.yaml`](https://github.com/icenet-ai/icenet-pipeline/blob/main/ensemble/predict.tmpl.yaml) found in the `icenet-pipeline` repo.

# %% [markdown]
# For the ensemble prediction, we define the dates we want to predict for in a csv file. This can be automatically generated from the dataset as follows.

# %%
# !./loader_test_dates.sh notebook_tutorial_pipeline_south | tee testdates.csv
# Out:
# 2023-02-15
# 2023-02-16

# %% [markdown]
# First look at the required input arguments for running the prediction ensemble.

# %%
# !./run_predict_ensemble.sh --help
# Out:
# Usage ./run_predict_ensemble.sh NETWORK DATASET NAME DATEFILE [LOADER]

# %% [markdown]
# So to to predict from an ensemble training run, we use:
#
# | argument  | description                                          | value                                     |
# |     ---:  |:---                                                  | :---                                      |
# |*NETWORK*  | Name of trained neural network to use for prediction | notebook_tutorial_pipeline_south_ensemble |
# |*DATASET*  | Name of dataset: dataset_config.{LOADER}.json        | notebook_tutorial_pipeline_south          |
# |*NAME*     | Name of output prediction                            | tutorial_south_ensemble_forecast          |
# |*DATEFILE* | Dates to predict for                                 | testdates.csv                             |
# |*LOADER*   | Name of loader: loader.{LOADER}.json (optional)      | -                                         |

# %%
# -f: n_filters_factor (matching the value used for training)
# -p: prep bash script (A bash script to run before running the prediction)
# !./run_predict_ensemble.sh -f 0.6 -p bashpc.sh notebook_tutorial_pipeline_south_ensemble notebook_tutorial_pipeline_south tutorial_south_ensemble_forecast testdates.csv
# Out:
# ARGS: -f 0.6 -p bashpc.sh notebook_tutorial_pipeline_south_ensemble notebook_tutorial_pipeline_south tutorial_south_ensemble_forecast testdates.csv
# ARGS = -x arg_filter_factor=0.6 arg_prep=bashpc.sh , Leftovers: notebook_tutorial_pipeline_south_ensemble notebook_tutorial_pipeline_south tutorial_south_ensemble_forecast testdates.csv
# No. of ensemble members:  2
# Ensemble members:  42,46
# Running model_ensemble ./tmp.FX0SxjDXVP.predict slurm -x arg_filter_factor=0.6 arg_prep=bashpc.sh
# [14-03-24 03:07:33    :INFO    ] - Model Ensemble Runner
# [14-03-24 03:07:33    :INFO    ] - Validated configuration file ./tmp.FX0SxjDXVP.predict successfully
# [14-03-24 03:07:33    :INFO    ] - Importing model_ensembler.cluster.slurm
# [14-03-24 03:07:33    :INFO    ] - Running batcher
# [14-03-24 03:07:33    :INFO    ] - Start batch: 2024-03-14 03:07:33.176467
# [14-03-24 03:07:33    :INFO    ] - Running cycle 1
# [14-03-24 03:07:33    :INFO    ] - Running command: /usr/bin/ln -s ../../data
# [14-03-24 03:07:33    :INFO    ] - Start run tutorial_south_ensemble_forecast-0 at 2024-03-14 03:07:33.253384
# [14-03-24 03:07:33    :INFO    ] - rsync -aXE ../template/ /data/hpcdata/users/bryald/git/icenet/blue/ensemble/tutorial_south_ensemble_forecast/tutorial_south_ensemble_forecast-0/
# [14-03-24 03:07:33    :INFO    ] - Start run tutorial_south_ensemble_forecast-1 at 2024-03-14 03:07:33.257901
# [14-03-24 03:07:33    :INFO    ] - rsync -aXE ../template/ /data/hpcdata/users/bryald/git/icenet/blue/ensemble/tutorial_south_ensemble_forecast/tutorial_south_ensemble_forecast-1/
# [14-03-24 03:07:33    :INFO    ] - Templating /data/hpcdata/users/bryald/git/icenet/blue/ensemble/tutorial_south_ensemble_forecast/tutorial_south_ensemble_forecast-0/icenet_predict.sh.j2 to /data/hpcdata/users/bryald/git/icenet/blue/ensemble/tutorial_south_ensemble_forecast/tutorial_south_ensemble_forecast-0/icenet_predict.sh
# [14-03-24 03:07:33    :INFO    ] - Templating /data/hpcdata/users/bryald/git/icenet/blue/ensemble/tutorial_south_ensemble_forecast/tutorial_south_ensemble_forecast-1/icenet_predict.sh.j2 to /data/hpcdata/users/bryald/git/icenet/blue/ensemble/tutorial_south_ensemble_forecast/tutorial_south_ensemble_forecast-1/icenet_predict.sh
# [14-03-24 03:07:33    :INFO    ] - Submitted job with ID 6052824
# [14-03-24 03:07:33    :WARNING ] - Could not retrieve job from list
# [14-03-24 03:07:34    :INFO    ] - Submitted job with ID 6052825
# [14-03-24 03:07:34    :WARNING ] - Could not retrieve job from list
# [14-03-24 03:14:07    :INFO    ] - tutorial_south_ensemble_forecast-0 monitor got state COMPLETED for job 6052824
# [14-03-24 03:14:07    :INFO    ] - End run tutorial_south_ensemble_forecast-0 at 2024-03-14 03:14:07.811368
# [14-03-24 03:14:07    :INFO    ] - tutorial_south_ensemble_forecast-1 monitor got state COMPLETED for job 6052825
# [14-03-24 03:14:07    :INFO    ] - End run tutorial_south_ensemble_forecast-1 at 2024-03-14 03:14:07.811865
# [14-03-24 03:14:07    :INFO    ] - Running command: icenet_output -m --nan -r ../.. -o ../../results/predict tutorial_south_ensemble_forecast notebook_tutorial_pipeline_south predict_dates.csv
# [14-03-24 03:14:14    :INFO    ] - Batch tutorial_south_ensemble_forecast completed: 2024-03-14 03:14:14.072987
# Removing temporary configuration ./tmp.FX0SxjDXVP.predict

# %% [markdown]
# As with the previous example, the individual numpy outputs, samples and sample weights are deposited into `/results/predict` for each ensemble member. However, the ensemble also runs `icenet_output` to generate __a CF-compliant NetCDF containing the forecasts requested__ which can then be post-processed or [deposited to an external location](#Uploading-to-Azure) (which is the platform for the [wider IceNet forecasting infrastructure](https://github.com/alan-turing-institute/IceNet-Project)).

# %%
# Numpy files location (under each ensemble directory listed in the output of this cell)
# !ls ./results/predict/tutorial_south_ensemble_forecast
# Out:
# notebook_tutorial_pipeline_south_ensemble.42
# notebook_tutorial_pipeline_south_ensemble.46

# %%
# Combined netCDF file location
# !ls ./results/predict/tutorial_south_ensemble_forecast.nc
# Out:
# ./results/predict/tutorial_south_ensemble_forecast.nc

# %% [markdown]
# ___
# # 5. Visualising

# %% [markdown]
# ## View the forecast output from the pipeline

# %% [markdown]
# Now that we have a prediction, we can visualise the binary sea ice concentration using some of the built-in tools in IceNet.
#
# (Note: There are also some scripts in the `icenet-pipeline` repository that enable plotting common results such as `produce_op_assets.sh`)

# %% [markdown]
# Here, we are loading the prediction netCDF file we've just created in the previous step.
#
# We are also using the `Masks` class from IceNet to create a land mask region to use to mask out the land regions in the prediction when plotting.

# %%
from icenet.plotting.video import xarray_to_video as xvid
from icenet.data.sic.mask import Masks
from IPython.display import HTML
import xarray as xr, pandas as pd, datetime as dt

# Load our output prediction file
ds = xr.open_dataset("results/predict/tutorial_south_ensemble_forecast.nc")
land_mask = Masks(south=True, north=False).get_land_mask()
ds.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	time = 2 ;
# 	yc = 432 ;
# 	xc = 432 ;
# 	leadtime = 7 ;
#
# variables:
# 	int32 Lambert_Azimuthal_Grid() ;
# 		Lambert_Azimuthal_Grid:grid_mapping_name = lambert_azimuthal_equal_area ;
# 		Lambert_Azimuthal_Grid:longitude_of_projection_origin = 0.0 ;
# 		Lambert_Azimuthal_Grid:latitude_of_projection_origin = -90.0 ;
# 		Lambert_Azimuthal_Grid:false_easting = 0.0 ;
# 		Lambert_Azimuthal_Grid:false_northing = 0.0 ;
# 		Lambert_Azimuthal_Grid:semi_major_axis = 6378137.0 ;
# 		Lambert_Azimuthal_Grid:inverse_flattening = 298.257223563 ;
# 		Lambert_Azimuthal_Grid:proj4_string = +proj=laea +lon_0=0 +datum=WGS84 +ellps=WGS84 +lat_0=-90.0 ;
# 	float32 sic_mean(time, yc, xc, leadtime) ;
# 		sic_mean:long_name = mean sea ice area fraction across ensemble runs of icenet model ;
# 		sic_mean:standard_name = sea_ice_area_fraction ;
# 		sic_mean:short_name = sic ;
# 		sic_mean:valid_min = 0 ;
# 		sic_mean:valid_max = 1 ;
# 		sic_mean:ancillary_variables = sic_stddev ;
# 		sic_mean:grid_mapping = Lambert_Azimuthal_Grid ;
# 		sic_mean:units = 1 ;
# 	float32 sic_stddev(time, yc, xc, leadtime) ;
# 		sic_stddev:long_name = total uncertainty (one standard deviation) of concentration of sea ice ;
# 		sic_stddev:standard_name = sea_ice_area_fraction standard_error ;
# 		sic_stddev:valid_min = 0 ;
# 		sic_stddev:valid_max = 1 ;
# 		sic_stddev:grid_mapping = Lambert_Azimuthal_Grid ;
# 		sic_stddev:units = 1 ;
# 	int64 ensemble_members(time) ;
# 		ensemble_members:long_name = number of ensemble members used to create this prediction ;
# 		ensemble_members:short_name = ensemble_members ;
# 	datetime64[ns] time(time) ;
# 		time:long_name = reference time of product ;
# 		time:standard_name = time ;
# 		time:axis = T ;
# 	int64 leadtime(leadtime) ;
# 		leadtime:long_name = leadtime of forecast in relation to reference time ;
# 		leadtime:short_name = leadtime ;
# 	datetime64[ns] forecast_date(time, leadtime) ;
# 	float64 xc(xc) ;
# 		xc:long_name = x coordinate of projection (eastings) ;
# 		xc:standard_name = projection_x_coordinate ;
# 		xc:units = 1000 meter ;
# 		xc:axis = X ;
# 	float64 yc(yc) ;
# 		yc:long_name = y coordinate of projection (northings) ;
# 		yc:standard_name = projection_y_coordinate ;
# 		yc:units = 1000 meter ;
# 		yc:axis = Y ;
# 	float32 lat(yc, xc) ;
# 		lat:long_name = latitude coordinate ;
# 		lat:standard_name = latitude ;
# 		lat:units = arc_degree ;
# 	float32 lon(yc, xc) ;
# 		lon:long_name = longitude coordinate ;
# 		lon:standard_name = longitude ;
# 		lon:units = arc_degree ;
#
# // global attributes:
# 	:Conventions = CF-1.6 ACDD-1.3 ;
# 	:comments =  ;
# 	:creator_email = jambyr@bas.ac.uk ;
# 	:creator_institution = British Antarctic Survey ;
# 	:creator_name = James Byrne ;
# 	:creator_url = www.bas.ac.uk ;
# 	:date_created = 2024-03-14 ;
# 	:geospatial_bounds_crs = EPSG:6932 ;
# 	:geospatial_lat_min = -90.0 ;
# 	:geospatial_lat_max = -16.62393 ;
# 	:geospatial_lon_min = -180.0 ;
# 	:geospatial_lon_max = 180.0 ;
# 	:geospatial_vertical_min = 0.0 ;
# 	:geospatial_vertical_max = 0.0 ;
# 	:history = 2024-03-14 03:14:13.350074 - creation ;
# 	:id = IceNet 0.2.7 ;
# 	:institution = British Antarctic Survey ;
# 	:keywords = 'Earth Science > Cryosphere > Sea Ice > Sea Ice Concentration
#             Earth Science > Oceans > Sea Ice > Sea Ice Concentration
#             Earth Science > Climate Indicators > Cryospheric Indicators > Sea Ice
#             Geographic Region > Southern Hemisphere ;
# 	:keywords_vocabulary = GCMD Science Keywords ;
# 	:license = Open Government Licece (OGL) V3 ;
# 	:naming_authority = uk.ac.bas ;
# 	:platform = BAS HPC ;
# 	:product_version = 0.2.7 ;
# 	:project = IceNet ;
# 	:publisher_email =  ;
# 	:publisher_institution = British Antarctic Survey ;
# 	:publisher_url =  ;
# 	:source =
#             IceNet model generation at v0.2.7
#              ;
# 	:spatial_resolution = 25.0 km grid spacing ;
# 	:standard_name_vocabulary = CF Standard Name Table v27 ;
# 	:summary =
#             This is an output of sea ice concentration predictions from the
#             IceNet run in an ensemble, with postprocessing to determine
#             the mean and standard deviation across the runs.
#              ;
# 	:time_coverage_start = 2023-02-16T00:00:00 ;
# 	:time_coverage_end = 2023-02-23T00:00:00 ;
# 	:time_coverage_duration = P1D ;
# 	:time_coverage_resolution = P1D ;
# 	:title = Sea Ice Concentration Prediction ;
# }

# %% [markdown]
# The next cell obtains the start date of the forecast

# %%
# Get the forecast start date
forecast_date = ds.time.values[0]
print(forecast_date)
# Out:
# 2023-02-15T00:00:00.000000000

# %% [markdown]
# And, here, we plot the forecast across the range of days we've defined within the `ENVS` file (93 days in this case).
#
# Since this is a demonstrator notebook, we have not trained our network for a prolonged period of time or for a large date range, but the plot below shows indicative results of what the output would look like.

# %%
fc = ds.sic_mean.isel(time=0).drop_vars("time").rename(dict(leadtime="time"))
fc['time'] = [pd.to_datetime(forecast_date) \
              + dt.timedelta(days=int(e)) for e in fc.time.values]

anim = xvid(fc, 15, figsize=4, mask=land_mask)
HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img0b176cd6dbf84a60b85eb3a6db6b71d9">
#   <div class="anim-controls">
#     <input id="_anim_slider0b176cd6dbf84a60b85eb3a6db6b71d9" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim0b176cd6dbf84a60b85eb3a6db6b71d9.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim0b176cd6dbf84a60b85eb3a6db6b71d9.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim0b176cd6dbf84a60b85eb3a6db6b71d9.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim0b176cd6dbf84a60b85eb3a6db6b71d9.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim0b176cd6dbf84a60b85eb3a6db6b71d9.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim0b176cd6dbf84a60b85eb3a6db6b71d9.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim0b176cd6dbf84a60b85eb3a6db6b71d9.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim0b176cd6dbf84a60b85eb3a6db6b71d9.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim0b176cd6dbf84a60b85eb3a6db6b71d9.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim0b176cd6dbf84a60b85eb3a6db6b71d9.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select0b176cd6dbf84a60b85eb3a6db6b71d9"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_0b176cd6dbf84a60b85eb3a6db6b71d9"
#              >
#       <label for="_anim_radio1_0b176cd6dbf84a60b85eb3a6db6b71d9">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_0b176cd6dbf84a60b85eb3a6db6b71d9"
#              checked>
#       <label for="_anim_radio2_0b176cd6dbf84a60b85eb3a6db6b71d9">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_0b176cd6dbf84a60b85eb3a6db6b71d9"
#              >
#       <label for="_anim_radio3_0b176cd6dbf84a60b85eb3a6db6b71d9">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img0b176cd6dbf84a60b85eb3a6db6b71d9";
#     var slider_id = "_anim_slider0b176cd6dbf84a60b85eb3a6db6b71d9";
#     var loop_select_id = "_anim_loop_select0b176cd6dbf84a60b85eb3a6db6b71d9";
#     var frames = new Array(7);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjguMywgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/H5lhTAAAACXBIWXMAABcS\
# AAAXEgFnn9JSAAEAAElEQV

# %% [markdown]
# ## Other Pipeline Considerations
#
# ### A bit more information on ensemble runs
#
# #### Cleaning up runs
#
# Ensemble runs take place under `/ensemble/` in the pipeline folder and ARE NOT deleted after they've happened, to allow for debugging. Commonly, the ensemble configurations will contain a delete task to remove the extraneous run folders. __In the meantime this should be done manually__ after running `run_train_ensemble` or `run_predict_ensemble`.
#
# The only exception to this is the use of `run_daily.sh` (see below) which does clean up prior to rerunning.
#
# ### Daily execution
#
# Daily execution is facilitated in the pipeline by using [`run_daily.sh`](https://github.com/antarctica/IceNet-Pipeline/blob/main/run_daily.sh). This wraps all the necessary steps to perform the following sequence for producing forecasts from yesterday for the next 93 days, for both northern and southern hemispheres.
#
# * Removes any old ensemble runs
# * Downloads [HRES forecast data from the ECMWF MARS API](https://www.ecmwf.int/en/forecasts/datasets/catalogue-ecmwf-real-time-products)
# * Processes the HRES and necessary training metadata to produce a data loader
# * Creates a dataset configuration for it
# * Runs a [prediction ensemble](#4-Predict) to produce a NetCDF
# * Uploads to the necessary endpoint
#
# #### Automation
#
# With the above shell script it's trivial to automate using cron. Of course this is simply for demonstration, with more complex workflow managers offering far great flexibility especially when considering analysis of the produced forecasts.
#
# ```bash
# # We assume your environment is configured appropriately to run conda from cron files, for example by adding...
# #
# # SHELL=/bin/bash
# # BASH_ENV=~/.bashrc_env
# #
# # With conda initialisation in bashrc_env at the top of your crontab
# 25 9 * * * conda activate icenet; cd $HOME/hpc/icenet/pipeline && bash run_daily.sh >$HOME/daily.log 2>&1; conda deactivate
# ```
#
# TODO: more information on the usage of this command.
#
# ## Summary
#
# Within this notebook we've attempted to give a full crash course on the IceNet pipeline and how to utilise it for a generalised run using the __pipeline helper scripts__. This is the second of six (currently) notebooks contained within the pipeline repository, covering further information:
#
# * [Data structure and analysis](03.data_and_forecasts.ipynb): understand the structure of the data stores and products created by these workflows and what tools currently exist in IceNet to looks over them.
# * [Library usage](04.library_usage.ipynb): understand how to programmatically perform an end to end run.
# * [Library extension](05.library_extension.ipynb): understand why and how to extend the IceNet library.
#
# ## Version
# - IceNet Codebase: v0.2.7
